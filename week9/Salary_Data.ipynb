# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd
# Import the stats library from numpy
from scipy import stats
# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
#Read f
salary_Data= pd.read_csv("Salary_Data.csv")

# %%
salary_Data
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
sns.scatterplot(x='Salary',y='Years of Experience',data=salary_Data)
# Out:
# <Axes: xlabel='Salary', ylabel='Years of Experience'>

# %%
salary_Data=salary_Data.dropna()

# %%
sns.regplot(x='Salary',y='Years of Experience',data=salary_Data)
# Out:
# <Axes: xlabel='Salary', ylabel='Years of Experience'>

# %% [markdown]
# postive Correlation

# %%
salary_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6698 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6698 non-null   float64
#  1   Gender               6698 non-null   object
#  2   Education Level      6698 non-null   object
#  3   Job Title            6698 non-null   object
#  4   Years of Experience  6698 non-null   float64
#  5   Salary               6698 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 366.3+ KB

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(salary_Data['Salary'],salary_Data['Years of Experience'])
print("y="+str(np.round(slope,2))+"x+"+str(np.round(intercept,2)))
# Out:
# y=0.0x+-4.8

# %%
#R square in a regression analysis is called the correlation coefficient 



slope, intercept, r_value, p_value, std_err
# Out:
# (9.286989644949646e-05,
#  -2.6154381243624787,
#  0.8089681695139432,
#  0.0,
#  8.247154606270898e-07)

# %%
stats.pearsonr(salary_Data['Salary'],salary_Data['Years of Experience'])
# Out:
# PearsonRResult(statistic=0.8089681695139437, pvalue=0.0)

# %%
#r**2
stats.pearsonr(salary_Data['Salary'],salary_Data['Years of Experience'])[0]**2
# Out:
# 0.6544294992867408

# %%
sns.residplot(x='Salary',y='Years of Experience',data=salary_Data)
# Out:
# <Axes: xlabel='Salary', ylabel='Years of Experience'>

# %%
sns.heatmap(salary_Data.corr(),annot=True,cmap='coolwarm',square=True)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_8048\3949758185.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(salary_Data.corr(),annot=True,cmap='coolwarm',square=True)
# <Axes: >
